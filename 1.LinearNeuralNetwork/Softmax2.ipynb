# %%
import torch
from torch import nn
from d2l import torch as d2l

batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %%
net = nn.Sequential(nn.Flatten(), nn.Linear(784, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

# %%
loss = nn.CrossEntropyLoss(reduction='none')

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.1)

# %%
num_epochs = 10
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# D:\Miniconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#
# D:\Miniconda3\envs\torch\lib\multiprocessing\queues.py in get(self, block, timeout)
#     104                     if not self._poll(timeout):
# --> 105                         raise Empty
#     106                 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11808\2261249115.py in <module>
#       1 num_epochs = 10
# ----> 2 d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
#
# D:\Miniconda3\envs\torch\lib\site-packages\d2l\torch.py in train_ch3(net, train_iter, test_iter, loss, num_epochs, updater)
#     352                         legend=['train loss', 'train acc', 'test acc'])
#     353     for epoch in range(num_epochs):
# --> 354         train_metrics = train_epoch_ch3(net, train_iter, loss, updater)
#     355         test_acc = evaluate_accuracy(net, test_iter)
#     356         animator.add(epoch + 1, train_metrics + (test_acc,))
#
# D:\Miniconda3\envs\torch\lib\site-packages\d2l\torch.py in train_epoch_ch3(net, train_iter, loss, updater)
#     287     # Sum of training loss, sum of training accuracy, no. of examples
#     288     metric = Accumulator(3)
# --> 289     for X, y in train_iter:
#     290         # Compute gradients and update parameters
#     291         y_hat = net(X)
#
# D:\Miniconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# D:\Miniconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# D:\Miniconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# D:\Miniconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#    1001             if len(failed_workers) > 0:
#    1002                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1003                 raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1004             if isinstance(e, queue.Empty):
#    1005                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 45836, 7884, 37536, 38064) exited unexpectedly
